# %%
#Datasets from Yahoo
URL = "https://finance.yahoo.com/quote/GOOG/history/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAADgKAIw8R5G5EDld4xwcKfDy-4pHRLkyy6MSV7CO-qSLp4RObjlKq9Ve75PbaTqJZBaQDK3kldwM1aGby9x9GOTACKjfEW788ZT1mOtqxhQG_rjoq9mRac97_NJGomhjGUhATCM3Oc6bH7F7sqTQGKOKAtXDlwL9C8BOEuZIAWmK"

# %%
#Import python packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Splitting a Dataset Into Training and Test Sets

"""
train: [0-2021]
test: [2022-X]

"""
print("Working")
# Out:
# Working

# %%
#Load Data
df = pd.read_csv("GOOG.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086
#
#        Volume
# 0  44871361.0
# 1  22942874.0
# 2  18342897.0
# 3  15319808.0
# 4   9232276.0

# %%
df.shape
# Out:
# (4393, 7)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
#Removing Null Values
df = df.dropna()
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4387  2022-01-21  2660.239990  2695.209961  2600.020020  2601.840088
# 4388  2022-01-24  2520.550049  2615.570068  2492.839111  2607.439941
# 4389  2022-01-25  2568.709961  2586.770020  2527.560059  2534.709961
# 4390  2022-01-26  2611.850098  2656.149902  2543.070068  2584.800049
# 4392  2022-01-28  2600.000000  2667.409912  2573.889893  2665.790039
#
#         Adj Close      Volume
# 0       49.982655  44871361.0
# 1       53.952770  22942874.0
# 2       54.495735  18342897.0
# ...

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4392.000000  4392.000000  4392.000000  4392.000000  4392.000000
# mean    671.752952   678.210924   665.329785   671.953874   671.953874
# std     623.234502   629.162658   617.802529   623.704194   623.704194
# min      49.409801    50.680038    47.800831    49.818268    49.818268
# 25%     246.481132   248.882133   242.650490   246.041523   246.041523
# 50%     425.933502   429.462769   422.334473   425.679443   425.679443
# 75%     966.985016   972.731765   956.604981   967.250015   967.250015
# max    3020.000000  3037.000000  2997.750000  3014.179932  3014.179932
#
#              Volume
# count  4.392000e+03
# mean   6.433066e+06
# std    7.794071e+06
# min    7.922000e+03
# 25%    1.561050e+06
# 50%    3.747594e+06
# 75%    8.119772e+06
# max    8.254163e+07

# %%
#Middle Value between Trainining/Test Sets
index = list(df.index.values)

# %%
df["Date"][4390].split("-")[0] == "2022"
# Out:
# True

# %%
for i in index:
    if df["Date"][i].split("-")[0] == "2022":
        imp_value = i
        break
        
print(imp_value)
# Out:
# 4374

# %%
#Train/Test


training_set = df[:imp_value]
test_set = df[imp_value:]

# %%
training_set
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4369  2021-12-27  2949.270020  2968.530029  2945.000000  2961.280029
# 4370  2021-12-28  2967.489990  2967.489990  2918.709961  2928.959961
# 4371  2021-12-29  2928.590088  2943.675049  2910.090088  2930.090088
# 4372  2021-12-30  2929.000000  2941.250000  2915.169922  2920.050049
# 4373  2021-12-31  2910.879883  2927.300049  2893.550049  2893.590088
#
#         Adj Close      Volume
# 0       49.982655  44871361.0
# 1       53.952770  22942874.0
# 2       54.495735  18342897.0
# ...

# %%
test_set
# Out:
#             Date         Open         High          Low        Close  \
# 4374  2022-01-03  2889.510010  2911.000000  2870.050049  2901.489990
# 4375  2022-01-04  2911.010010  2932.199951  2876.322998  2888.330078
# 4376  2022-01-05  2883.620117  2885.959961  2750.469971  2753.070068
# 4377  2022-01-06  2749.949951  2793.719971  2735.270020  2751.020020
# 4378  2022-01-07  2758.100098  2765.094971  2715.780029  2740.090088
# 4379  2022-01-10  2701.979980  2772.800049  2662.810059  2771.479980
# 4380  2022-01-11  2763.610107  2806.590088  2736.270020  2800.350098
# 4381  2022-01-12  2831.090088  2856.284912  2822.239990  2832.959961
# 4382  2022-01-13  2836.810059  2863.709961  2778.280029  2782.620117
# 4383  2022-01-14  2750.000000  2824.010010  2750.000000  2795.729980
# 4384  2022-01-18  2732.000000  2747.830078  2712.340088  2725.810059
# 4385  2022-01-19  2738.770020  2767.989990  2710.000000  2713.040039
# 4386  2022-01-20  2730.280029  2758.239990  2662.889893  2670.129883
# ...

# %%
training_set = training_set.iloc[:,1:2]
training_set.head()
# Out:
#         Open
# 0  49.813290
# 1  50.316402
# 2  55.168217
# 3  55.412300
# 4  52.284027

# %%
training_set = training_set.values
training_set
# Out:
# array([[  49.81329 ],
#        [  50.316402],
#        [  55.168217],
#        ...,
#        [2928.590088],
#        [2929.      ],
#        [2910.879883]])

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
training_set = sc.fit_transform(training_set)
training_set
# Out:
# array([[1.35827890e-04],
#        [3.05192214e-04],
#        [1.93847539e-03],
#        ...,
#        [9.69228367e-01],
#        [9.69366357e-01],
#        [9.63266520e-01]])

# %%
len(training_set)
# Out:
# 4374

# %%
# Getting the inputs and the ouputs
X_train = training_set[0:4373]
y_train = training_set[1:4374]

# Sample

t_x_0 = pd.DataFrame(X_train[0:5])
t_x_1= pd.DataFrame(y_train[0:5])
sa = pd.concat([t_x_0, t_x_1], axis=1)
sa.columns = (['t_x_0', 't_x_1'])
sa
# Out:
#       t_x_0     t_x_1
# 0  0.000136  0.000305
# 1  0.000305  0.001938
# 2  0.001938  0.002021
# 3  0.002021  0.000968
# 4  0.000968  0.000966

# %%
# Reshaping into required shape for Keras
X_train = np.reshape(X_train, (4373, 1, 1))
X_train
# Out:
# array([[[1.35827890e-04]],
#
#        [[3.05192214e-04]],
#
#        [[1.93847539e-03]],
#
#        ...,
#
#        [[9.82323375e-01]],
#
#        [[9.69228367e-01]],
#
#        [[9.69366357e-01]]])

# %%
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

"""
What Are LSTMs? LSTM (Long Short-Term Memory) is a Recurrent Neural Network (RNN) based architecture that is widely used in natural language processing and time series forecasting.
Using a series of 'gates,' each with its own RNN, the LSTM manages to keep, forget or ignore data points based on a probabilistic model


"""

#A recurrent neural network (RNN) is a type of artificial neural network which uses sequential data or time series data. 
print("Working")
# Out:
# Working

# %%
# Initializing the Recurrent Neural Network
model = Sequential()

# %%
# Adding the input layer and the LSTM layer


#(conda install numpy=1.19.5 --> RESTART THE KERNEL)
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# %%
# Adding the output layer
model.add(Dense(units = 1))

# %%
# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
model.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 137/137 [==============================] - 0s 854us/step - loss: 0.0406
# Epoch 2/200
# 137/137 [==============================] - 0s 796us/step - loss: 0.0351
# Epoch 3/200
# 137/137 [==============================] - 0s 759us/step - loss: 0.0304
# Epoch 4/200
# 137/137 [==============================] - 0s 773us/step - loss: 0.0256
# Epoch 5/200
# 137/137 [==============================] - 0s 782us/step - loss: 0.0208
# Epoch 6/200
# 137/137 [==============================] - 0s 773us/step - loss: 0.0162
# Epoch 7/200
# 137/137 [==============================] - 0s 795us/step - loss: 0.0120
# Epoch 8/200
# 137/137 [==============================] - 0s 790us/step - loss: 0.0083
# Epoch 9/200
# 137/137 [==============================] - 0s 824us/step - loss: 0.0054
# Epoch 10/200
# 137/137 [==============================] - 0s 855us/step - loss: 0.0032
# Epoch 11/200
# 137/137 [==============================] - 0s 832us/step - loss: 0.0018
# Epoch 12/200
# ...

# %%
#TESTING 1

# %%
test_set.head()
# Out:
#             Date         Open         High          Low        Close  \
# 4374  2022-01-03  2889.510010  2911.000000  2870.050049  2901.489990
# 4375  2022-01-04  2911.010010  2932.199951  2876.322998  2888.330078
# 4376  2022-01-05  2883.620117  2885.959961  2750.469971  2753.070068
# 4377  2022-01-06  2749.949951  2793.719971  2735.270020  2751.020020
# 4378  2022-01-07  2758.100098  2765.094971  2715.780029  2740.090088
#
#         Adj Close     Volume
# 4374  2901.489990  1260700.0
# 4375  2888.330078  1146400.0
# 4376  2753.070068  2482100.0
# 4377  2751.020020  1452500.0
# 4378  2740.090088   970100.0

# %%
test_set.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 4387  2022-01-21  2660.239990  2695.209961  2600.020020  2601.840088
# 4388  2022-01-24  2520.550049  2615.570068  2492.839111  2607.439941
# 4389  2022-01-25  2568.709961  2586.770020  2527.560059  2534.709961
# 4390  2022-01-26  2611.850098  2656.149902  2543.070068  2584.800049
# 4392  2022-01-28  2600.000000  2667.409912  2573.889893  2665.790039
#
#         Adj Close     Volume
# 4387  2601.840088  2087000.0
# 4388  2607.439941  2764600.0
# 4389  2534.709961  1800400.0
# 4390  2584.800049  1981500.0
# 4392  2665.790039  1524200.0

# %%
#Visualization of test_set
for index, row in test_set.iterrows():
    print(row['Date'], index)
# Out:
# 2022-01-03 4374
# 2022-01-04 4375
# 2022-01-05 4376
# 2022-01-06 4377
# 2022-01-07 4378
# 2022-01-10 4379
# 2022-01-11 4380
# 2022-01-12 4381
# 2022-01-13 4382
# 2022-01-14 4383
# 2022-01-18 4384
# 2022-01-19 4385
# 2022-01-20 4386
# 2022-01-21 4387
# 2022-01-24 4388
# 2022-01-25 4389
# 2022-01-26 4390
# 2022-01-28 4392

# %%
# Getting relevant feature
real_stock_price = (test_set.iloc[:,1:2])
real_stock_price.head()
# Out:
#              Open
# 4374  2889.510010
# 4375  2911.010010
# 4376  2883.620117
# 4377  2749.949951
# 4378  2758.100098

# %%
real_stock_price.tail()
# Out:
#              Open
# 4387  2660.239990
# 4388  2520.550049
# 4389  2568.709961
# 4390  2611.850098
# 4392  2600.000000

# %%
#real_stock_price = real_stock_price.loc[4375:4375 , "Open"]
print("A single query")
# Out:
# A single query

# %%
# Converting to 2D array
real_stock_price = real_stock_price.values

# %%
# Getting the predicted stock price of 2022

#18 VALUES
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (18, 1, 1))
predicted_stock_price = model.predict(inputs)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
print(predicted_stock_price)
# Out:
# [[2874.1372]
#  [2893.7341]
#  [2868.7583]
#  [2745.447 ]
#  [2753.031 ]
#  [2700.6382]
#  [2758.1538]
#  [2820.5767]
#  [2825.8408]
#  [2745.4934]
#  [2728.713 ]
#  [2735.029 ]
#  [2727.1077]
#  [2661.419 ]
#  [2528.677 ]
#  [2574.693 ]
#  [2615.6902]
#  [2604.45  ]]

# %%
# Visualizing the results
plt.plot(real_stock_price, color = 'green', label = 'Real Alphabet Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Alphabet Stock Price')
plt.title('Alphabet Stock Price Prediction')
plt.xlabel('Days')
plt.ylabel('Alphabet Stock Price')
plt.legend()
plt.show()

# %%
#TESTING 2

# %%
test_set.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 4387  2022-01-21  2660.239990  2695.209961  2600.020020  2601.840088
# 4388  2022-01-24  2520.550049  2615.570068  2492.839111  2607.439941
# 4389  2022-01-25  2568.709961  2586.770020  2527.560059  2534.709961
# 4390  2022-01-26  2611.850098  2656.149902  2543.070068  2584.800049
# 4392  2022-01-28  2600.000000  2667.409912  2573.889893  2665.790039
#
#         Adj Close     Volume
# 4387  2601.840088  2087000.0
# 4388  2607.439941  2764600.0
# 4389  2534.709961  1800400.0
# 4390  2584.800049  1981500.0
# 4392  2665.790039  1524200.0

# %%
test_set = test_set.append({"Date": "2022-01-31", "Open": 2665.790039}, ignore_index=True)

# %%
test_set.tail()
# Out:
#           Date         Open         High          Low        Close  \
# 14  2022-01-24  2520.550049  2615.570068  2492.839111  2607.439941
# 15  2022-01-25  2568.709961  2586.770020  2527.560059  2534.709961
# 16  2022-01-26  2611.850098  2656.149902  2543.070068  2584.800049
# 17  2022-01-28  2600.000000  2667.409912  2573.889893  2665.790039
# 18  2022-01-31  2665.790039          NaN          NaN          NaN
#
#       Adj Close     Volume
# 14  2607.439941  2764600.0
# 15  2534.709961  1800400.0
# 16  2584.800049  1981500.0
# 17  2665.790039  1524200.0
# 18          NaN        NaN

# %%
# Getting relevant feature
real_stock_price = test_set.iloc[:,1:2]
real_stock_price.head()
# Out:
#           Open
# 0  2889.510010
# 1  2911.010010
# 2  2883.620117
# 3  2749.949951
# 4  2758.100098

# %%
# Converting to 2D array
real_stock_price = real_stock_price.values

# %%
# Getting the predicted stock price of 2022

#19 VALUES
inputs = real_stock_price
inputs = sc.transform(inputs)
inputs = np.reshape(inputs, (19, 1, 1))
predicted_stock_price = regressor.predict(inputs)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualizing the results
plt.plot(real_stock_price, color = 'green', label = 'Real Alphabet Stock Price')
plt.plot(predicted_stock_price, color = 'red', label = 'Predicted Alphabet Stock Price')
plt.title('Alphabet Stock Price Prediction')
plt.xlabel('Days')
plt.ylabel('Alphabet Stock Price')
plt.legend()
plt.show()

# %%
predicted_stock_price
# Out:
# array([[2871.7163],
#        [2890.7617],
#        [2866.4856],
#        [2746.2031],
#        [2753.6213],
#        [2702.328 ],
#        [2758.63  ],
#        [2819.5706],
#        [2824.7017],
#        [2746.2493],
#        [2729.8286],
#        [2736.0105],
#        [2728.2566],
#        [2663.8562],
#        [2533.1895],
#        [2578.5632],
#        [2618.92  ],
#        [2607.862 ],
#        [2668.9875]], dtype=float32)

# %%
real_stock_price
# Out:
# array([[2889.51001 ],
#        [2911.01001 ],
#        [2883.620117],
#        [2749.949951],
#        [2758.100098],
#        [2701.97998 ],
#        [2763.610107],
#        [2831.090088],
#        [2836.810059],
#        [2750.      ],
#        [2732.      ],
#        [2738.77002 ],
#        [2730.280029],
#        [2660.23999 ],
#        [2520.550049],
#        [2568.709961],
#        [2611.850098],
#        [2600.      ],
#        [2665.790039]])
